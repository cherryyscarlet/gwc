# %%
for i in range (1, 101):
    if i % 3 == 0:
        print("buzz")
    if i % 5 ==0:
        print("fizz")
    if i % 3== 0 and i % 5 == 0:
        print("fizzbuzz")
    else: 
        print(i)
# Out:
# 1
# 2
# buzz
# 3
# 4
# fizz
# 5
# buzz
# 6
# 7
# 8
# buzz
# 9
# fizz
# 10
# 11
# buzz
# 12
# 13
# 14
# buzz
# fizz
# fizzbuzz
# 16
# 17
# buzz
# 18
# 19
# fizz
# 20
# buzz
# 21
# 22
# 23
# buzz
# 24
# fizz
# 25
# 26
# buzz
# 27
# 28
# 29
# buzz
# fizz
# fizzbuzz
# 31
# 32
# buzz
# 33
# 34
# fizz
# 35
# buzz
# 36
# 37
# 38
# buzz
# 39
# fizz
# 40
# 41
# buzz
# 42
# 43
# 44
# buzz
# fizz
# fizzbuzz
# 46
# 47
# buzz
# 48
# 49
# fizz
# 50
# buzz
# 51
# 52
# 53
# buzz
# 54
# fizz
# 55
# 56
# buzz
# 57
# 58
# 59
# buzz
# fizz
# fizzbuzz
# 61
# 62
# buzz
# 63
# 64
# fizz
# 65
# buzz
# 66
# 67
# 68
# buzz
# 69
# fizz
# 70
# 71
# buzz
# 72
# 73
# 74
# buzz
# fizz
# fizzbuzz
# 76
# 77
# buzz
# 78
# 79
# fizz
# 80
# buzz
# 81
# 82
# 83
# buzz
# 84
# fizz
# 85
# 86
# buzz
# 87
# 88
# 89
# buzz
# fizz
# fizzbuzz
# 91
# 92
# buzz
# 93
# 94
# fizz
# 95
# buzz
# 96
# 97
# 98
# buzz
# 99
# fizz
# 100
